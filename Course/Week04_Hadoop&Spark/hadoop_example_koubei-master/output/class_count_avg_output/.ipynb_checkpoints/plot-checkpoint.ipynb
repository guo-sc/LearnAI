# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import ch
ch.set_ch()

# %%
import pandas as pd

# %%
payNum = pd.read_csv('part-00000', sep='\t', header=None, encoding='gbk')

# %%
pay_num_table = payNum.iloc[:, :].set_index([1, 0]).unstack().dropna()

# %%
pay_num_table.columns = pay_num_table.columns.get_level_values(1)

# %%
pay_num_table.index = pay_num_table.index.map(pd.Timestamp)

# %%
pay_num_table.index.name=None
pay_num_table.columns.name=None

# %%
pay_num_table.head()
# Out:
#             个人护理         中餐        休闲茶饮       休闲食品         便利店       其他美食  \
# 2016-08-04  36.0  82.125000  111.426667  78.254237  148.014778  82.534884
# 2016-08-05  34.0  88.513889  133.960526  88.239669  155.117647  96.860465
# 2016-08-06  33.0  92.438356  113.673203  89.016393   99.631841  99.395349
# 2016-08-07  44.0  90.273973  113.506579  89.811475   92.611940  98.318182
# 2016-08-08  26.0  80.583333   93.185430  86.225000  152.099502  88.704545
#
#                    小吃          快餐   本地购物  汤/粥/煲/砂锅/炖菜          火锅        烘焙糕点  \
# 2016-08-04  79.864662  135.679032  114.0   126.833333   76.939394  100.727273
# 2016-08-05  90.351145  152.496785  163.0   134.500000   88.393939  108.200000
# 2016-08-06  80.223881  129.930979  225.0    80.666667  102.882353  105.100000
# 2016-08-07  80.704545  123.488746  198.0    66.166667   99.088235  106.109091
# 2016-08-08  82.007519  120.782400  145.0   143.000000   78.575758  104.445455
#
#                     烧烤  网吧网咖  美容美发    药店          超市
# 2016-08-04   66.444444  66.5  48.0  35.0  169.292818
# 2016-08-05   80.111111  76.5  62.0  35.0  202.451791
# 2016-08-06   95.888889  91.0  73.0  42.0  242.906849
# 2016-08-07  102.222222  98.0  65.0  39.5  250.578082
# 2016-08-08   68.111111  72.0  70.0  40.5  184.021918

# %%
ax = pay_num_table[-31:].plot(figsize=(12,7))
ax.legend(prop={'size':15})

# %%
plt.legend(loc=0, numpoints=1)
leg = plt.gca().get_legend()
ltext  = leg.get_texts()
plt.setp(ltext, fontsize='small')
# Out:
# D:\Python36\lib\site-packages\matplotlib\axes\_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-2500ff93a6bc> in <module>()
#       1 plt.legend(loc=0, numpoints=1)
#       2 leg = plt.gca().get_legend()
# ----> 3 ltext  = leg.get_texts()
#       4 plt.setp(ltext, fontsize='small')
#
# AttributeError: 'NoneType' object has no attribute 'get_texts'
