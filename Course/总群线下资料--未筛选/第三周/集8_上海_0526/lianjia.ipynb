# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline

plt.rcParams['font.sans-serif']=['SimHei'] # 中文显示

# %%
lianjia_df = pd.read_csv('data/lianjia.csv')
lianjia_df.head()
# Out:
#   Direction District Elevator  Floor    Garden            Id Layout   Price  \
# 0        东西      灯市口      NaN      6  锡拉胡同21号院  101102647043   3室1厅   780.0
# 1        南北       东单      无电梯      6     东华门大街  101102650978   2室1厅   705.0
# 2        南西      崇文门      有电梯     16     新世界中心  101102672743   3室1厅  1400.0
# 3         南      崇文门      NaN      7    兴隆都市馨园  101102577410   1室1厅   420.0
# 4         南      陶然亭      有电梯     19    中海紫御公馆  101102574696   2室2厅   998.0
#
#   Region Renovation   Size  Year
# 0     东城         精装   75.0  1988
# 1     东城         精装   60.0  1988
# 2     东城         其他  210.0  1996
# 3     东城         精装   39.0  2004
# 4     东城         精装   90.0  2010

# %%
# 检查缺失值情况
lianjia_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23677 entries, 0 to 23676
# Data columns (total 12 columns):
# Direction     23677 non-null object
# District      23677 non-null object
# Elevator      15440 non-null object
# Floor         23677 non-null int64
# Garden        23677 non-null object
# Id            23677 non-null int64
# Layout        23677 non-null object
# Price         23677 non-null float64
# Region        23677 non-null object
# Renovation    23677 non-null object
# Size          23677 non-null float64
# Year          23677 non-null int64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 2.2+ MB

# %%
lianjia_df.describe() # 看下统计分布
# Out:
#               Floor            Id         Price          Size          Year
# count  23677.000000  2.367700e+04  23677.000000  23677.000000  23677.000000
# mean      12.765088  1.011024e+11    610.668319     99.149301   2001.326519
# std        7.643932  5.652477e+05    411.452107     50.988838      9.001996
# min        1.000000  1.010886e+11     60.000000      2.000000   1950.000000
# 25%        6.000000  1.011022e+11    365.000000     66.000000   1997.000000
# 50%       11.000000  1.011025e+11    499.000000     88.000000   2003.000000
# 75%       18.000000  1.011027e+11    717.000000    118.000000   2007.000000
# max       57.000000  1.011028e+11   6000.000000   1019.000000   2017.000000

# %%
# 添加新特征房屋均价
df = lianjia_df.copy()
df['PerPrice'] = lianjia_df['Price']/lianjia_df['Size']
# 调整列顺序
columns = ['Region', 'District', 'Garden', 'Layout', 'Floor', 'Year', 'Size', 'Elevator', 'Direction', 'Renovation', 'PerPrice', 'Price']
df = pd.DataFrame(df, columns = columns)
df.head()
# Out:
#   Region District    Garden Layout  Floor  Year   Size Elevator Direction  \
# 0     东城      灯市口  锡拉胡同21号院   3室1厅      6  1988   75.0      NaN        东西
# 1     东城       东单     东华门大街   2室1厅      6  1988   60.0      无电梯        南北
# 2     东城      崇文门     新世界中心   3室1厅     16  1996  210.0      有电梯        南西
# 3     东城      崇文门    兴隆都市馨园   1室1厅      7  2004   39.0      NaN         南
# 4     东城      陶然亭    中海紫御公馆   2室2厅     19  2010   90.0      有电梯         南
#
#   Renovation   PerPrice   Price
# 0         精装  10.400000   780.0
# 1         精装  11.750000   705.0
# 2         其他   6.666667  1400.0
# 3         精装  10.769231   420.0
# 4         精装  11.088889   998.0

# %%
# 对二手房区域分组对比二手房数量和每平米房价
df_house_count = df.groupby('Region')['Price'].count().sort_values(ascending=False).to_frame().reset_index()
df_house_mean = df.groupby('Region')['PerPrice'].mean().sort_values(ascending=False).to_frame().reset_index()
# 准备绘图
f, [ax1,ax2,ax3] = plt.subplots(3,1,figsize=(20,15))
sns.barplot(x='Region', y='PerPrice', palette="Blues_d", data=df_house_mean, ax=ax1)
ax1.set_title('北京各大区二手房每平米单价对比',fontsize=15)
ax1.set_xlabel('区域')
ax1.set_ylabel('每平米单价')

sns.barplot(x='Region', y='Price', palette="Greens_d", data=df_house_count, ax=ax2)
ax2.set_title('北京各大区二手房数量对比',fontsize=15)
ax2.set_xlabel('区域')
ax2.set_ylabel('数量')

sns.boxplot(x='Region', y='Price', data=df, ax=ax3)
ax3.set_title('北京各大区二手房房屋总价',fontsize=15)
ax3.set_xlabel('区域')
ax3.set_ylabel('房屋总价')

plt.show()

# %%
f, [ax1,ax2] = plt.subplots(1, 2, figsize=(15, 5))
# 面积的分布情况
sns.distplot(df['Size'], bins=20, ax=ax1, color='r')
sns.kdeplot(df['Size'], shade=True, ax=ax1)
# 面积和出售价格的关系
sns.regplot(x='Size', y='Price', data=df, ax=ax2)
plt.show()
# Out:
# C:\Users\regdz\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df.loc[df['Size']< 10]
# Out:
#       Region District   Garden Layout  Floor  Year  Size Elevator Direction  \
# 1168      房山       长阳     世茂维拉   叠拼别墅      5  2015   5.0       毛坯  240.97平米
# 1458      房山       长阳     世茂维拉   叠拼别墅      5  2015   5.0       毛坯  242.78平米
# 1797      房山       长阳     世茂维拉   叠拼别墅      5  2015   5.0       精装  242.96平米
# 2268      顺义     顺义其它    龙湖好望山   叠拼别墅      4  2014   4.0       精装  295.88平米
# 2274      顺义     顺义其它     鹭峯国际   叠拼别墅      4  2014   5.0       精装  295.01平米
# 2276      顺义     顺义其它    龙湖好望山   叠拼别墅      3  2014   4.0       毛坯  292.31平米
# 2432      顺义     顺义其它    龙湖好望山   叠拼别墅      5  2013   6.0       精装  294.42平米
# 4078      大兴      西红门    鸿坤林语墅   叠拼别墅      3  2015   4.0       精装   427.5平米
# 4079      大兴      西红门    鸿坤林语墅   叠拼别墅      4  2015   4.0       精装   361.8平米
# 4761      大兴      西红门    鸿坤林语墅   叠拼别墅      3  2015   5.0       精装  386.83平米
# 7533      昌平      回龙观   龙城花园N区   叠拼别墅      4  1997   2.0       简装  107.93平米
# 8765      通州     通州其它     旭辉御锦   叠拼别墅      6  2014   5.0       毛坯  195.32平米
# 9020      通州     通州其它     旭辉御锦   叠拼别墅      6  2014   4.0       精装  259.87平米
# 9080      通州     通州其它     旭辉御锦   叠拼别墅      6  2014   4.0       毛坯  259.76平米
# 9203      通州     通州其它     旭辉御锦   叠拼别墅      6  2014   4.0       精装  260.07平米
# 9254      通州     通州其它     旭辉御锦   叠拼别墅      6  2014   4.0       毛坯   264.6平米
# 11531     丰台       丽泽     西宸原著   叠拼别墅      6  2016   4.0       毛坯  335.51平米
# 14298     海淀       西山   中间建筑一区   叠拼别墅      3  2007   8.0       精装  266.61平米
# 15334     海淀       西山  西山美墅馆F区   叠拼别墅      4  2004   4.0       简装  203.73平米
# 17311     朝阳      大望路     首府官邸   叠拼别墅      5  2007   5.0       精装   523.4平米
#
#       Renovation     PerPrice   Price
# 1168          南北   216.000000  1080.0
# 1458          南北   220.000000  1100.0
# 1797          南北   196.000000   980.0
# 2268          南北   250.000000  1000.0
# 2274          南北   290.000000  1450.0
# 2276          南北   215.000000   860.0
# 2432          南北   163.333333   980.0
# 4078          南北   787.500000  3150.0
# 4079          南北   595.000000  2380.0
# 4761          南北   540.000000  2700.0
# 7533          南北   310.000000   620.0
# 8765          南北   156.000000   780.0
# 9020          南北   280.000000  1120.0
# 9080          南北   262.500000  1050.0
# 9203          南北   262.500000  1050.0
# 9254          南北   275.000000  1100.0
# 11531         南北  1000.000000  4000.0
# 14298         南北   168.750000  1350.0
# 15334         南北   550.000000  2200.0
# 17311         南北   900.000000  4500.0

# %%
tmp_df = df[df['Layout']=='叠拼别墅']
tmp_df['Size'] = tmp_df['Direction']
tmp_df['Size'] = tmp_df['Size'].apply(lambda s: s[:s.find('平米')])
df.update(tmp_df)
df[df['Layout']=='叠拼别墅']
# Out:
# C:\Users\regdz\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\regdz\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       Region District   Garden Layout  Floor    Year    Size Elevator  \
# 1168      房山       长阳     世茂维拉   叠拼别墅    5.0  2015.0  240.97       毛坯
# 1458      房山       长阳     世茂维拉   叠拼别墅    5.0  2015.0  242.78       毛坯
# 1797      房山       长阳     世茂维拉   叠拼别墅    5.0  2015.0  242.96       精装
# 2268      顺义     顺义其它    龙湖好望山   叠拼别墅    4.0  2014.0  295.88       精装
# 2274      顺义     顺义其它     鹭峯国际   叠拼别墅    4.0  2014.0  295.01       精装
# 2276      顺义     顺义其它    龙湖好望山   叠拼别墅    3.0  2014.0  292.31       毛坯
# 2432      顺义     顺义其它    龙湖好望山   叠拼别墅    5.0  2013.0  294.42       精装
# 4078      大兴      西红门    鸿坤林语墅   叠拼别墅    3.0  2015.0   427.5       精装
# 4079      大兴      西红门    鸿坤林语墅   叠拼别墅    4.0  2015.0   361.8       精装
# 4761      大兴      西红门    鸿坤林语墅   叠拼别墅    3.0  2015.0  386.83       精装
# 7533      昌平      回龙观   龙城花园N区   叠拼别墅    4.0  1997.0  107.93       简装
# 8765      通州     通州其它     旭辉御锦   叠拼别墅    6.0  2014.0  195.32       毛坯
# 9020      通州     通州其它     旭辉御锦   叠拼别墅    6.0  2014.0  259.87       精装
# 9080      通州     通州其它     旭辉御锦   叠拼别墅    6.0  2014.0  259.76       毛坯
# 9203      通州     通州其它     旭辉御锦   叠拼别墅    6.0  2014.0  260.07       精装
# 9254      通州     通州其它     旭辉御锦   叠拼别墅    6.0  2014.0   264.6       毛坯
# 11531     丰台       丽泽     西宸原著   叠拼别墅    6.0  2016.0  335.51       毛坯
# 14298     海淀       西山   中间建筑一区   叠拼别墅    3.0  2007.0  266.61       精装
# 15334     海淀       西山  西山美墅馆F区   叠拼别墅    4.0  2004.0  203.73       简装
# 17311     朝阳      大望路     首府官邸   叠拼别墅    5.0  2007.0   523.4       精装
#
#       Direction Renovation     PerPrice   Price
# 1168   240.97平米         南北   216.000000  1080.0
# 1458   242.78平米         南北   220.000000  1100.0
# 1797   242.96平米         南北   196.000000   980.0
# 2268   295.88平米         南北   250.000000  1000.0
# 2274   295.01平米         南北   290.000000  1450.0
# 2276   292.31平米         南北   215.000000   860.0
# 2432   294.42平米         南北   163.333333   980.0
# 4078    427.5平米         南北   787.500000  3150.0
# 4079    361.8平米         南北   595.000000  2380.0
# 4761   386.83平米         南北   540.000000  2700.0
# 7533   107.93平米         南北   310.000000   620.0
# 8765   195.32平米         南北   156.000000   780.0
# 9020   259.87平米         南北   280.000000  1120.0
# 9080   259.76平米         南北   262.500000  1050.0
# 9203   260.07平米         南北   262.500000  1050.0
# 9254    264.6平米         南北   275.000000  1100.0
# 11531  335.51平米         南北  1000.000000  4000.0
# 14298  266.61平米         南北   168.750000  1350.0
# 15334  203.73平米         南北   550.000000  2200.0
# 17311   523.4平米         南北   900.000000  4500.0

# %%
df.loc[df['Size'].astype(float)>1000]
# Out:
# Empty DataFrame
# Columns: [Region, District, Garden, Layout, Floor, Year, Size, Elevator, Direction, Renovation, PerPrice, Price]
# Index: []

# %%
df = df[(df['Layout']!='叠拼别墅')&(df['Size'].astype(float)<1000)] # 过滤不正常面积
# Out:
#       Region District     Garden Layout  Floor    Year Size Elevator  \
# 0         东城      灯市口   锡拉胡同21号院   3室1厅    6.0  1988.0   75      NaN
# 1         东城       东单      东华门大街   2室1厅    6.0  1988.0   60      无电梯
# 2         东城      崇文门      新世界中心   3室1厅   16.0  1996.0  210      有电梯
# 3         东城      崇文门     兴隆都市馨园   1室1厅    7.0  2004.0   39      NaN
# 4         东城      陶然亭     中海紫御公馆   2室2厅   19.0  2010.0   90      有电梯
# 5         东城      广渠门     幸福家园二期   2室1厅   18.0  2003.0  111      有电梯
# 6         东城      西罗园  西革新里110号院   1室1厅    6.0  1992.0   42      无电梯
# 7         东城      西罗园        建予园   2室1厅   16.0  1999.0  105      有电梯
# 8         东城      东花市      富贵园一区   3室2厅    9.0  2003.0  161      有电梯
# 9         东城      东直门    万国城MOMA   2室2厅   25.0  2002.0  127      有电梯
# 10        东城       工体      十字坡东里   1室1厅    5.0  1986.0   37      无电梯
# 11        东城      地安门   帽儿胡同45号院   2室1厅    5.0  1985.0   50      无电梯
# 12        东城      广渠门       金桥国际   1室1厅   19.0  2004.0   54      有电梯
# 13        东城      崇文门       太华公寓   1室0厅   18.0  2000.0   64      有电梯
# 14        西城      菜户营        信德园   3室1厅   23.0  2002.0  146      有电梯
# 15        西城      木樨地     西便门外大街   2室0厅    4.0  1957.0   50      无电梯
# 16        西城       马甸      双旗杆东里   2室1厅   18.0  1986.0   58      NaN
# 17        西城      马连道        第三区  2房间2卫   18.0  2011.0   33      有电梯
# 18        西城      六铺炕      六铺炕二区   3室1厅   17.0  1990.0   78      有电梯
# 19        西城      广安门     荣丰2008   1室0厅   26.0  2006.0   28      有电梯
# 20        西城       牛街      平原里小区   2室1厅   12.0  1999.0   59      有电梯
# 21        西城      木樨地      真武庙六里   2室1厅   18.0  1988.0   78      有电梯
# 22        西城     右安门内     右安门内大街   1室1厅    7.0  1991.0   45      无电梯
# 23        西城      西直门      玉桃园二区   2室1厅    6.0  1997.0   60      无电梯
# 24        西城      马连道       红莲南里   2室1厅    7.0  1992.0   61      无电梯
# 25        西城       牛街     白广路6号院   3室0厅    6.0  1955.0   84      NaN
# 26        朝阳    亚运村小营      育慧里一区   1室0厅    7.0  2001.0   52      有电梯
# 27        朝阳       望京    大西洋新城A区   2室2厅   10.0  1999.0   86      有电梯
# 28        朝阳      团结湖       团结湖路   2室1厅    6.0  1980.0   65      无电梯
# 29        朝阳      三元桥    尚家楼48号院   2室1厅   12.0  1998.0   75      有电梯
# ...      ...      ...        ...    ...    ...     ...  ...      ...
# 23647     东城      和平里      和平里七区   2室1厅    6.0  1995.0   69      NaN
# 23648     东城       工体       工体北里   2室1厅    6.0  1984.0   54      NaN
# 23649     东城       安贞      小黄庄二区   4室1厅   12.0  1996.0  122      NaN
# 23650     东城      广渠门       广渠家园   1室1厅   29.0  2009.0   51      NaN
# 23651     东城      和平里      和平里七区   2室1厅    6.0  1989.0   56      无电梯
# 23652     东城      东直门   北官厅胡同2号院   2室1厅    6.0  1985.0   59      NaN
# 23653     东城     朝阳门内       仓南胡同   2室1厅    6.0  2003.0   71      NaN
# 23654     东城      安定门   鼓楼外大街52号   2室1厅   11.0  1992.0   62      NaN
# 23655     东城      崇文门       新裕家园   3室1厅   12.0  2004.0  125      NaN
# 23656     东城      崇文门     新景家园西区   3室1厅   16.0  2004.0   91      NaN
# 23657     东城      金宝街   史家胡同20号院   2室0厅    5.0  1980.0   46      NaN
# 23658     东城       工体        春秀路   2室1厅    9.0  1998.0   59      NaN
# 23659     东城     朝阳门内      西水井胡同   2室1厅   16.0  2003.0   74      NaN
# 23660     东城      东直门  民安小区东羊管胡同   2室1厅   14.0  2002.0   73      NaN
# 23661     东城      左安门       左安漪园   3室1厅   15.0  2004.0  113      NaN
# 23662     东城      和平里      和平里九区   3室1厅    6.0  1990.0   67      NaN
# 23663     东城      和平里      和平里二区   2室1厅   20.0  2006.0   79      NaN
# 23664     东城      和平里      和平里三区   1室1厅    6.0  1996.0   40      NaN
# 23665     东城      永定门        定安里   3室1厅    6.0  1984.0   64      NaN
# 23666     东城      陶然亭     中海紫御公馆   2室1厅   23.0  2010.0   63      有电梯
# 23667     东城      永定门        定安里   2室1厅    6.0  1984.0   55      NaN
# 23668     东城      东直门      海运仓小区   3室1厅    6.0  2003.0   82      NaN
# 23669     东城      广渠门        京禧阁   2室1厅   22.0  2013.0  119      NaN
# 23670     东城      交道口       土儿胡同   2室1厅    6.0  2002.0   69      NaN
# 23671     东城      和平里        甘水桥   3室1厅    5.0  1983.0   56      NaN
# 23672     东城      广渠门       保利蔷薇   2室1厅   16.0  2008.0   97      NaN
# 23673     东城      永定门       郭庄北里   2室1厅    6.0  1995.0   66      NaN
# 23674     东城      和平里       康鸿家园   3室2厅    6.0  2000.0  155      NaN
# 23675     东城       前门  台基厂头条10号院   4室1厅    6.0  1990.0  107      NaN
# 23676     东城      崇文门     新景家园东区   1室1厅   15.0  2008.0   81      NaN
#
#       Direction Renovation   PerPrice   Price
# 0            东西         精装  10.400000   780.0
# 1            南北         精装  11.750000   705.0
# 2            南西         其他   6.666667  1400.0
# 3             南         精装  10.769231   420.0
# 4             南         精装  11.088889   998.0
# 5            南北         其他  10.630631  1180.0
# 6             南         其他   7.595238   319.0
# 7             南         其他   6.095238   640.0
# 8            南北         精装  11.055901  1780.0
# 9            东北         精装  10.236220  1300.0
# 10            南         精装  10.945946   405.0
# 11            南         其他  14.000000   700.0
# 12            西         精装   8.555556   462.0
# 13            西         精装   8.093750   518.0
# 14           西南         其他   6.575342   960.0
# 15            东         简装   9.140000   457.0
# 16           西北         简装  10.517241   610.0
# 17            北         精装  10.303030   340.0
# 18           西南         其他  14.358974  1120.0
# 19            北         精装  11.428571   320.0
# 20           南北         简装  10.101695   596.0
# 21           南北         精装  11.384615   888.0
# 22           西北         其他   9.000000   405.0
# 23           南北         简装  10.833333   650.0
# 24           南北         精装   7.704918   470.0
# 25            南         简装   7.559524   635.0
# 26            西         精装   6.596154   343.0
# 27           南北         精装   9.709302   835.0
# 28           东西         精装   6.615385   430.0
# 29           南北         精装   8.133333   610.0
# ...         ...        ...        ...     ...
# 23647        东南         精装   9.420290   650.0
# 23648        东西         毛坯   9.074074   490.0
# 23649       东南北         简装  10.655738  1300.0
# 23650         西         精装   8.529412   435.0
# 23651        西南         简装   9.642857   540.0
# 23652        南北         精装  11.016949   650.0
# 23653        东南         简装  13.211268   938.0
# 23654         东         简装  11.048387   685.0
# 23655        南北         精装  10.344000  1293.0
# 23656        东西         精装   9.560440   870.0
# 23657       南西北         精装  14.913043   686.0
# 23658         南         简装   9.694915   572.0
# 23659        东西         简装   9.445946   699.0
# 23660        南北         精装  10.410959   760.0
# 23661         东         精装   8.407080   950.0
# 23662        南北         简装  10.000000   670.0
# 23663         西         精装  10.126582   800.0
# 23664        西南         简装  10.750000   430.0
# 23665        东北         精装   6.546875   419.0
# 23666        西北         简装   9.507937   599.0
# 23667        南北         精装   6.636364   365.0
# 23668        南北         简装  11.585366   950.0
# 23669        西南         精装   8.823529  1050.0
# 23670        南北         简装  12.753623   880.0
# 23671        南北         简装  10.089286   565.0
# 23672        南北         简装  10.412371  1010.0
# 23673        南北         简装   7.090909   468.0
# 23674        南北         简装   9.032258  1400.0
# 23675        南北         简装  10.280374  1100.0
# 23676        南北         精装   9.753086   790.0
#
# [23656 rows x 12 columns]

# %%
# 重新可视化
f, [ax1,ax2] = plt.subplots(1, 2, figsize=(15, 5))
# 建房时间的分布情况
sns.distplot(df['Size'], bins=20, ax=ax1, color='r')
sns.kdeplot(df['Size'], shade=True, ax=ax1)
# 建房时间和出售价格的关系
sns.regplot(x='Size', y='Price', data=df, ax=ax2)
plt.show()
# Out:
# C:\Users\regdz\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# 户型特征分析
# 但是仔细观察特征分类下有很多不规则的命名，比如2室一厅与2房间1卫，还有别墅，没有统一的叫法。
# 这样的特征肯定是不能作为机器学习模型的数据输入的，需要使用特征工程进行相应的处理。
f, ax1= plt.subplots(figsize=(20,20))
sns.countplot(y='Layout', data=df, ax=ax1)
ax1.set_title('房屋户型',fontsize=15)
ax1.set_xlabel('数量')
ax1.set_ylabel('户型')
plt.show()

# %%
# 装修特征
df['Renovation'].value_counts()
# Out:
# 精装    11345
# 简装     8496
# 其他     3239
# 毛坯      576
# Name: Renovation, dtype: int64

# %%
f, [ax1,ax2,ax3] = plt.subplots(1, 3, figsize=(20, 5))
sns.countplot(df['Renovation'], ax=ax1)
sns.barplot(x='Renovation', y='Price', data=df, ax=ax2)
sns.boxplot(x='Renovation', y='Price', data=df, ax=ax3)
plt.show()

# %%
# 分析电梯
misn = len(df.loc[(df['Elevator'].isnull()), 'Elevator'])
print('Elevator缺失值数量为：'+ str(misn))
# Out:
# Elevator缺失值数量为：8237

# %%
# 考虑填补法，但是有无电梯不是数值，不存在平均值和中位数，怎么填补呢？
# 这里给大家提供一种思路：就是根据楼层 Floor 来判断有无电梯。
# 一般的楼层大于6的都有电梯，而小于等于6层的一般都没有电梯。有了这个标准，那么剩下的就简单了。
df['Elevator'] = df.loc[(df['Elevator'] == '有电梯')|(df['Elevator'] == '无电梯'), 'Elevator']
# 填补Elevator缺失值
df.loc[(df['Floor']>6)&(df['Elevator'].isnull()), 'Elevator'] = '有电梯'
df.loc[(df['Floor']<=6)&(df['Elevator'].isnull()), 'Elevator'] = '无电梯'
f, [ax1,ax2] = plt.subplots(1, 2, figsize=(20, 10))
sns.countplot(df['Elevator'], ax=ax1)
ax1.set_title('有无电梯数量对比',fontsize=15)
ax1.set_xlabel('是否有电梯')
ax1.set_ylabel('数量')
sns.barplot(x='Elevator', y='Price', data=df, ax=ax2)
ax2.set_title('有无电梯房价对比',fontsize=15)
ax2.set_xlabel('是否有电梯')
ax2.set_ylabel('总价')
plt.show()

# %%
# 年代分析
grid = sns.FacetGrid(df, row='Elevator', col='Renovation', palette='seismic',size=4)
grid.map(plt.scatter, 'Year', 'Price')
grid.add_legend()
# 结论
# 整个二手房房价趋势是随着时间增长而增长的；
# 2000年以后建造的二手房房价相较于2000年以前有很明显的价格上涨；
# 1980年之前几乎不存在有电梯二手房数据，说明1980年之前还没有大面积安装电梯；
# 1980年之前无电梯二手房中，简装二手房占绝大多数，精装反而很少；

# %%
# 楼层分析
f, ax1= plt.subplots(figsize=(20,5))
sns.countplot(x='Floor', data=df, ax=ax1)
ax1.set_title('房屋户型',fontsize=15)
ax1.set_xlabel('楼层')
ax1.set_ylabel('数量')
plt.show()
