# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from pylab import *
# %matplotlib inline

# %%
ax = plt.subplot(111)
ax.spines["right"].set_color("none")
ax.spines["top"].set_color("none")
# ax.xaxis.set_ticks_position("bottom")
ax.spines["bottom"].set_position(("data", 0))
ax.spines["left"].set_position(("data", 0))

# 构造数据
x = np.linspace(-np.pi, np.pi, 256, endpoint=True)
c = np.cos(x)
s = np.sin(x)
ax.plot(x, c, color="blue", linewidth=2.5, linestyle="-", label="cosine")
ax.plot(x, s, color="red", linewidth=2.5, linestyle="-", label="sine")

plt.xlim(x.min()*1.1, x.max()*1.1)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$\pi/2$', r'$\pi$']) #latex

plt.ylim(c.min() * 1.1, c.max() * 1.1)
plt.yticks([-1, 1],
          [r'$-1$', r'$+1$'])

# ax.arrow(xmin, 0, xmax-xmin, 0., fc='k', ec='k', lw = lw, 
#              head_width=hw, head_length=hl, overhang = ohg, 
#              length_includes_head= True, clip_on = False) 

plt.legend(frameon=False)
plt.title("Cosine and Sine")

t = 2 * np.pi / 3
plt.scatter([t, ], [np.cos(t), ], 50, color='blue')
plt.plot([t, t], [0, np.cos(t)], color='blue', linewidth=1.5, linestyle="--")
plt.annotate(r'$\cos(\frac{2\pi}{3})$', xy=(t, np.cos(t)), xycoords="data", xytext=(-90, -50), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))
# Out:
# Text(-90, -50, '$\\cos(\\frac{2\\pi}{3})$')

# %%
# rc: resource configuration
matplotlib.rc('figure', figsize = (14, 7))
# 设置字体 14
matplotlib.rc('font', size = 14)
# 不显示顶部和右侧的坐标线 
matplotlib.rc('axes.spines', top = False, right = False)
# 不显示网格
matplotlib.rc('axes', grid = False)
# 设置背景颜色是白色
matplotlib.rc('axes', facecolor = 'white')

nvda = pd.read_csv("data/nvda.csv", index_col=0, parse_dates=[0])
# nvda.plot()

ax1 = subplot(2,1,1)
# _, ax1 = plt.subplots()
ax1.plot(nvda.index, nvda["Adj Close"], color = "blue")
# 添加标题和坐标说明
ax1.set_ylabel("Adj Close", color = "blue")
ax1.set_xlabel("Date")
ax1.set_title("Nvidia Close stock price")

ax2 = subplot(212)
# ax2 = ax1.twinx() # 两个绘图对象共享横坐标轴
ax2.stackplot(nvda.index, nvda["Volume"], color = "grey", alpha=0.3)
ax2.set_ylabel("Volume", color = "grey")
# ax2.set_ylim(0, nvda["Volume"].max()*5)
# # 右侧坐标轴可见
ax2.spines['right'].set_visible(True)
